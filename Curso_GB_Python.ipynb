# %% [markdown]
# <a href="https://colab.research.google.com/github/afraniofilho/Curso-GB-com-Python/blob/main/Curso_GB_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Curso Python/MICRODADOS_ENEM_2018_resumo.csv', sep=';', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    Unnamed: 0  NU_IDADE  TP_COR_RACA Q006  NU_NOTA_MT TP_SEXO
# 0           0      44.0            1    A         NaN       M
# 1           1      23.0            3    B       480.3       F
# 2           2      23.0            1    C         NaN       F
# 3           3      26.0            3    B         NaN       F
# 4           4      20.0            0    B         NaN       M

# %%
df.shape
# Out:
# (5513747, 6)

# %%
df.NU_IDADE.tail()
# Out:
# 5513742    56.0
# 5513743    20.0
# 5513744    17.0
# 5513745    17.0
# 5513746    21.0
# Name: NU_IDADE, dtype: float64

# %%
df.NU_IDADE.isnull().sum()
# Out:
# 97

# %%
df.NU_IDADE.count()
# Out:
# 5513650

# %%
df.NU_IDADE.mean()
# Out:
# 22.372219854361447

# %%
df.NU_IDADE.dropna().mean()
# Out:
# 22.372219854361447

# %%
df.NU_IDADE.std()
# Out:
# 7.594597160633532

# %%
df.NU_IDADE.dropna().std()
# Out:
# 7.594597160633532

# %%
print('%.2f' %df.NU_IDADE.dropna().mean())
# Out:
# 22.37

# %%
plt.hist(df.NU_IDADE);

# %%
plt.bar(height=df.TP_COR_RACA.value_counts(), x=('Não declarado', 'Branca', 'Preta', 'Parda', 'Amarela','Indígena'))
# Out:
# <BarContainer object of 6 artists>

# %%
tipos = ('Nenhuma renda',
    'Até R$ 954,00',
    'De R$ 954,01 até R$ 1.431,00',
    'De R$ 1.431,01 até R$ 1.908,00',
    'De R$ 1.908,01 até R$ 2.385,00',
    'De R$ 2.385,01 até R$ 2.862,00',
    'De R$ 2.862,01 até R$ 3.816,00',
    'De R$ 3.816,01 até R$ 4.770,00',
    'De R$ 4.770,01 até R$ 5.724,00',
    'De R$ 5.724,01 até R$ 6.678,00',
    'De R$ 6.678,01 até R$ 7.632,00',
    'De R$ 7.632,01 até R$ 8.586,00',
    'De R$ 8.586,01 até R$ 9.540,00',
    'De R$ 9.540,01 até R$ 11.448,00',
    'De R$ 11.448,01 até R$ 14.310,00',
    'De R$ 14.310,01 até R$ 19.080,00',
    'Mais de R$ 19.080,00')

# %%
tipos
# Out:
# ('Nenhuma renda',
#  'Até R$ 954,00',
#  'De R$ 954,01 até R$ 1.431,00',
#  'De R$ 1.431,01 até R$ 1.908,00',
#  'De R$ 1.908,01 até R$ 2.385,00',
#  'De R$ 2.385,01 até R$ 2.862,00',
#  'De R$ 2.862,01 até R$ 3.816,00',
#  'De R$ 3.816,01 até R$ 4.770,00',
#  'De R$ 4.770,01 até R$ 5.724,00',
#  'De R$ 5.724,01 até R$ 6.678,00',
#  'De R$ 6.678,01 até R$ 7.632,00',
#  'De R$ 7.632,01 até R$ 8.586,00',
#  'De R$ 8.586,01 até R$ 9.540,00',
#  'De R$ 9.540,01 até R$ 11.448,00',
#  'De R$ 11.448,01 até R$ 14.310,00',
#  'De R$ 14.310,01 até R$ 19.080,00',
#  'Mais de R$ 19.080,00')

# %%
plt.barh(y=tipos, width = df.Q006.value_counts());

# %%
df.loc[df.NU_IDADE == 'NaN']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, NU_IDADE, TP_COR_RACA, Q006, NU_NOTA_MT, TP_SEXO]
# Index: []

# %%
df.NU_IDADE.isnull().sum()
# Out:
# 97

# %%
df[df['NU_IDADE'].isnull()]
# Out:
#          Unnamed: 0  NU_IDADE  TP_COR_RACA Q006  NU_NOTA_MT TP_SEXO
# 21235         21235       NaN            1    J       673.8       F
# 190501       190501       NaN            3    B       378.1       F
# 215893       215893       NaN            2    B       517.7       M
# 295074       295074       NaN            3    H       574.4       F
# 355160       355160       NaN            1    C         NaN       F
# 361203       361203       NaN            1    B         NaN       F
# 405909       405909       NaN            3    B       627.8       F
# 671514       671514       NaN            3    B       607.1       F
# 726804       726804       NaN            3    B         NaN       M
# 732722       732722       NaN            3    B         NaN       F
# 998721       998721       NaN            3    E       590.4       F
# 1397226     1397226       NaN            1    C         NaN       F
# 1421724     1421724       NaN            1    A       422.5       F
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    Unnamed: 0  NU_IDADE  TP_COR_RACA Q006  NU_NOTA_MT TP_SEXO
# 0           0      44.0            1    A         NaN       M
# 1           1      23.0            3    B       480.3       F
# 2           2      23.0            1    C         NaN       F
# 3           3      26.0            3    B         NaN       F
# 4           4      20.0            0    B         NaN       M

# %%
plt.hist(df.NU_NOTA_MT)
# Out:
# (array([8.720000e+02, 0.000000e+00, 0.000000e+00, 2.165670e+05,
#         1.449745e+06, 1.236169e+06, 6.564650e+05, 3.038150e+05,
#         3.797300e+04, 3.493000e+03]),
#  array([  0.  ,  99.61, 199.22, 298.83, 398.44, 498.05, 597.66, 697.27,
#         796.88, 896.49, 996.1 ]),
#  <a list of 10 Patch objects>)

# %%
df.loc[df.NU_NOTA_MT > 990]
# Out:
#          Unnamed: 0  NU_IDADE  TP_COR_RACA Q006  NU_NOTA_MT TP_SEXO
# 4080           4080      18.0            1    I       993.0       M
# 10865         10865      17.0            1    H       992.0       M
# 160196       160196      18.0            1    Q       996.1       M
# 414829       414829      18.0            1    P       990.7       M
# 512693       512693      18.0            1    O       994.4       M
# 516955       516955      20.0            1    E       996.1       M
# 604615       604615      18.0            1    M       996.1       M
# 634003       634003      17.0            1    O       990.3       M
# 1014373     1014373      19.0            1    Q       993.0       M
# 1028471     1028471      31.0            1    K       996.1       M
# 1203353     1203353      18.0            1    Q       990.4       M
# 1231303     1231303      17.0            3    M       994.4       M
# 1237665     1237665      17.0            3    N       994.4       M
# ...

# %%
df[df.NU_NOTA_MT > 990]
# Out:
#          Unnamed: 0  NU_IDADE  TP_COR_RACA Q006  NU_NOTA_MT TP_SEXO
# 4080           4080      18.0            1    I       993.0       M
# 10865         10865      17.0            1    H       992.0       M
# 160196       160196      18.0            1    Q       996.1       M
# 414829       414829      18.0            1    P       990.7       M
# 512693       512693      18.0            1    O       994.4       M
# 516955       516955      20.0            1    E       996.1       M
# 604615       604615      18.0            1    M       996.1       M
# 634003       634003      17.0            1    O       990.3       M
# 1014373     1014373      19.0            1    Q       993.0       M
# 1028471     1028471      31.0            1    K       996.1       M
# 1203353     1203353      18.0            1    Q       990.4       M
# 1231303     1231303      17.0            3    M       994.4       M
# 1237665     1237665      17.0            3    N       994.4       M
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# NU_IDADE       float64
# TP_COR_RACA      int64
# Q006            object
# NU_NOTA_MT     float64
# TP_SEXO         object
# dtype: object

# %%
df.loc[(df.NU_IDADE > 80) | (df.NU_NOTA_MT < 00)]
# Out:
#          Unnamed: 0  NU_IDADE  TP_COR_RACA Q006  NU_NOTA_MT TP_SEXO
# 64523         64523      86.0            1    N       396.5       M
# 204452       204452      87.0            1    M       503.5       M
# 336912       336912      81.0            1    C       446.7       M
# 947434       947434      85.0            1    C         NaN       M
# 1026388     1026388      81.0            1    D       430.2       M
# 1036388     1036388      82.0            3    B       588.2       M
# 1055265     1055265      85.0            1    F       544.3       M
# 1184488     1184488      89.0            1    B         NaN       F
# 1383589     1383589      85.0            1    J       381.0       F
# 1709506     1709506      82.0            3    B         NaN       M
# 1982952     1982952      82.0            1    F         NaN       M
# 2066935     2066935      82.0            3    B       420.3       M
# 2084058     2084058      82.0            1    B       525.2       M
# ...

# %%
df.TP_SEXO.value_counts(normalize=True)
# Out:
# F    0.590833
# M    0.409167
# Name: TP_SEXO, dtype: float64

# %%
percF = (df.TP_SEXO.value_counts(normalize=True))[0]

# %%
percF
# Out:
# 0.5908328764450019

# %%
percM = (df.TP_SEXO.value_counts(normalize=True))[1]

# %%
percM
# Out:
# 0.40916712355499807

# %%
print('O percentual de M é {0:.2f}% e de F é {1:.2f}%'.format(percM * 100, percF * 100))
# Out:
# O percentual de M é 40.92% e de F é 59.08%

# %%
plt.pie(x= df.TP_SEXO.value_counts(normalize=True), labels=['Feminino', 'Masculino'], autopct='%1.1f%%');

# %%
plt.scatter(x='NU_IDADE', y='NU_NOTA_MT', data=df)
